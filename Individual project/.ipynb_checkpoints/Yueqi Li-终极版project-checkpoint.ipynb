# %% [markdown]
#         Data Science: A Programming Approach
#         Mahyar S Vaghefi
#         University of Texas Arlington
#
#         This document can only be used for class studies.
#         You are not allowed to share it in any public platform.

# %% [markdown]
# <h1 align='center' style="color: blue;">Individual Project - Fall 2020</h1>

# %% [markdown]
# You need to work on a popular Fashion MNIST dataset for this project. The dataset includes tiny images of fashion pieces. The objective is to create a set of supervised learning models that can predict the type of item based on its image. You can use all different models that you learned about them in this course for yourr work. Keep in mind that this is a project, not a class assignmnet. So, not all steps are predetermined and you have more flexibility, and the final outcome is likely to be more detailed.

# %% [markdown]
# In order to load the dataset you need to have `tensorflow V2` on your computer. Use the following code to install the package

# %%
#!pip install --upgrade tensorflow
#!pip install keras
# Out:
# Collecting keras
#   Using cached Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\liyue\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: pyyaml in c:\users\liyue\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in c:\users\liyue\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\liyue\anaconda3\lib\site-packages (from keras) (1.5.0)
# Requirement already satisfied: six in c:\users\liyue\appdata\roaming\python\python38\site-packages (from h5py->keras) (1.14.0)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %% [markdown]
# You can also check the version of it using the following code.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.1'

# %% [markdown]
# Now, it's time to load the dataset

# %%
from tensorflow import keras
#from keras.utils import np_utils
fashion_mnist = keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# As can be seen from the above code, the dataset was divided into train and test sets. Let's take a look at the X_train

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# As it is clear, the train dataset (`X_train`) contains 60,000 images of size 28 x 28. We can visualize one of the images using the following code:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

sample_image = X_train[1]
plt.imshow(sample_image, cmap='binary')
plt.axis('off')
plt.show()

# %% [markdown]
# The `y_train` also includes values between 0 and 9. Each represents a particular category. For example, we can check the value of `y_train` for the above image.

# %%
y_train[1]
# Out:
# 0

# %% [markdown]
# The above code shows that the image belongs to category 0. To get the associated label with each category, you can use the following code:

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
print(class_names[y_train[1]])
# Out:
# T-shirt/top

# %% [markdown]
# Now, it's your turn,

# %% [markdown]
# <ul>
#     <li><b>Task1:</b> Use the train set to train various supervised models and evaluate their performance using the test set.</li>
#     <ul>
#         <li>Use different supervised learning models.</li>
#         <li>Use different metrics such as <b>accutacy</b>, <b>precision</b>, <b>AUC</b>, and ... in your model evaluation. </li>
#         <li>It is not enough to report the metrics. It is crucial that you interpret the metrics for each model and compare them across different models.</li>
#         <li> You may need to use the cross validation methods for hyperparameter selection.</li>
#         <li> Specify the model that outperforms the other models.</b>
#     </ul>
#     <li><b>Task2:</b> Use the best model to predict your own fashion pieces.</li>
#     <ul>
#         <li>Take a picture of five fashion pieces of your own (take pictures in square format).</li>
#         <li>Resize images to the correct size (28,28).</li>
#         <li>Grayscale your images.</li>
#         <li>Visualize all the images side by side</li>
#         <li>Use the best model in Task 1 to predict the label of each of your own images.</li>
#         <li>How accurate is the final result?</li>
#     </ul>
# </ul>

# %% [markdown]
# #### Task 1

# %%
#探索数据
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from sklearn.metrics import classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-0853c2710e4a> in <module>
#       1 #探索数据
# ----> 2 from keras.utils import np_utils
#       3 from keras.models import Sequential
#       4 from keras.layers import Dense
#       5 from keras.optimizers import SGD
#
# ModuleNotFoundError: No module named 'keras'

# %%
print("The shape of train_images is ",X_train.shape)
print("The shape of train_labels is ",y_train.shape)
print("The shape of test_images is ",X_test.shape)
print("The length of test_labels is ",len(y_test))

# %%
plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.gca().grid(False)
plt.show()

# %%
# normalize to range 0-1 将像素值缩小到 0 到 1 之间
X_train=X_train/255.0
X_test=X_test/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_train[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
    
plt.show()

# %% [markdown]
# - 神经网络

# %%
from sklearn.model_selection import GridSearchCV

def create_model(layer):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(layer, activation='relu'),
        keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = keras.wrappers.scikit_learn.KerasClassifier(create_model)
param_grid = {'layer': [32, 64, 128, 256]}
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1)
grid_result = grid.fit(X_train,y_train)
# Out:
# 1500/1500 [==============================] - 1s 786us/step - loss: 0.5790 - accuracy: 0.8010
# 375/375 [==============================] - 0s 537us/step - loss: 0.4434 - accuracy: 0.8494
# 1500/1500 [==============================] - 1s 721us/step - loss: 0.5729 - accuracy: 0.8021
# 375/375 [==============================] - 0s 678us/step - loss: 0.4656 - accuracy: 0.8363
# 1500/1500 [==============================] - 1s 741us/step - loss: 0.5713 - accuracy: 0.8044
# 375/375 [==============================] - 0s 527us/step - loss: 0.4347 - accuracy: 0.8505
# 1500/1500 [==============================] - 1s 750us/step - loss: 0.5688 - accuracy: 0.8032
# 375/375 [==============================] - 0s 559us/step - loss: 0.4656 - accuracy: 0.8449
# 1500/1500 [==============================] - 1s 761us/step - loss: 0.5758 - accuracy: 0.8032
# 375/375 [==============================] - 0s 654us/step - loss: 0.4481 - accuracy: 0.8479
# 1500/1500 [==============================] - 1s 859us/step - loss: 0.5444 - accuracy: 0.8111
# 375/375 [==============================] - 0s 718us/step - loss: 0.4399 - accuracy: 0.8442
# 1500/1500 [==============================] - 1s 907us/step - loss: 0.5369 - accuracy: 0.8145
# 375/375 [==============================] - 0s 612us/step - loss: 0.4499 - accuracy: 0.8348
# 1500/1500 [==============================] - 1s 852us/step - loss: 0.5372 - accuracy: 0.8137
# 375/375 [==============================] - 0s 641us/step - loss: 0.4427 - accuracy: 0.8460
# 1500/1500 [==============================] - 1s 971us/step - loss: 0.5387 - accuracy: 0.8123
# 375/375 [==============================] - 0s 758us/step - loss: 0.4467 - accuracy: 0.8447
# 1500/1500 [==============================] - 1s 959us/step - loss: 0.5330 - accuracy: 0.8156
# 375/375 [==============================] - 0s 641us/step - loss: 0.4591 - accuracy: 0.8362
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5268 - accuracy: 0.8175
# 375/375 [==============================] - 0s 673us/step - loss: 0.4675 - accuracy: 0.8374
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5158 - accuracy: 0.8206
#   1/375 [..............................] - ETA: 0s - loss: 0.3569 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_test_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_begin` time: 0.0011s). Check your callbacks.
# 375/375 [==============================] - 0s 670us/step - loss: 0.4169 - accuracy: 0.8503
# 1500/1500 [==============================] - 1s 1000us/step - loss: 0.5192 - accuracy: 0.8185
# 375/375 [==============================] - 0s 662us/step - loss: 0.4246 - accuracy: 0.8497
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5244 - accuracy: 0.8149
# 375/375 [==============================] - 0s 654us/step - loss: 0.4449 - accuracy: 0.8430
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5142 - accuracy: 0.8177
# 375/375 [==============================] - 0s 654us/step - loss: 0.4256 - accuracy: 0.8487
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4994 - accuracy: 0.8235
# 375/375 [==============================] - 0s 806us/step - loss: 0.4141 - accuracy: 0.8500
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4985 - accuracy: 0.8244
# 375/375 [==============================] - 0s 846us/step - loss: 0.3968 - accuracy: 0.8568
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5079 - accuracy: 0.8196
# 375/375 [==============================] - 0s 830us/step - loss: 0.4075 - accuracy: 0.8545
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4996 - accuracy: 0.8227
# 375/375 [==============================] - 0s 945us/step - loss: 0.3903 - accuracy: 0.8633
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5018 - accuracy: 0.8236
# 375/375 [==============================] - 0s 856us/step - loss: 0.4083 - accuracy: 0.8533
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4828 - accuracy: 0.8288

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import classification_report, confusion_matrix
import sklearn.metrics as metrics
import numpy as np


best_model = create_model(grid_result.best_params_['layer'])
best_model.fit(X_train, y_train)
predict = best_model.predict(X_test)


#print('accuracy: ', accuracy)

print("\n--------------------classification_report------------------")

print(metrics.classification_report (y_test, np.argmax(predict, axis = 1),target_names=class_names))
# Out:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4847 - accuracy: 0.8284
#
# --------------------classification_report------------------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.77      0.84      0.80      1000
#      Trouser       0.81      0.98      0.89      1000
#     Pullover       0.70      0.81      0.75      1000
#        Dress       0.90      0.73      0.81      1000
#         Coat       0.72      0.79      0.75      1000
#       Sandal       0.95      0.95      0.95      1000
#        Shirt       0.77      0.48      0.59      1000
#      Sneaker       0.88      0.96      0.92      1000
#          Bag       0.97      0.95      0.96      1000
#   Ankle boot       0.98      0.91      0.94      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc, roc_curve
from sklearn.metrics import  f1_score, auc, roc_curve
best_model = create_model(grid_result.best_params_['layer'])
best_model.fit(X_train, y_train)
predict = best_model.predict(X_test)
predict = predict.argmax(1)

accuracy = accuracy_score(y_test, predict)
precision = precision_score(y_test, predict, average='micro')
recall = recall_score(y_test, predict, average='micro')
f1 = f1_score(y_test, predict, average='micro')



print('accuracy: ', accuracy, 'precision: ', precision, 'recall: ', recall ,'f1 :' , f1)
# Out:
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.4818 - accuracy: 0.8281
# accuracy:  0.8531 precision:  0.8531 recall:  0.8531 f1 : 0.8531

# %%
# Fit the model

history = best_model.fit(X_train,y_train,epochs=10,validation_split=0.3)
print(history.history['loss'])
print(history.history['accuracy'])
print(history.history['val_loss'])
print(history.history['val_accuracy'])



# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left') 
plt.show()

# summarize history for loss plt.plot(history.history['loss']) plt.plot(history.history['val_loss']) plt.title('model loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left') 
plt.show()

#plot the training loss and accuracy

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 10), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 10), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 10), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 10), history.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch number ")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")
plt.show()
# Out:
# Epoch 1/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3677 - accuracy: 0.8651 - val_loss: 0.3735 - val_accuracy: 0.8663
# Epoch 2/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3300 - accuracy: 0.8779 - val_loss: 0.3505 - val_accuracy: 0.8733
# Epoch 3/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3073 - accuracy: 0.8856 - val_loss: 0.3237 - val_accuracy: 0.8824
# Epoch 4/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2909 - accuracy: 0.8927 - val_loss: 0.3330 - val_accuracy: 0.8793
# Epoch 5/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2735 - accuracy: 0.8984 - val_loss: 0.3235 - val_accuracy: 0.8828
# Epoch 6/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2595 - accuracy: 0.9025 - val_loss: 0.3303 - val_accuracy: 0.8832
# Epoch 7/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2473 - accuracy: 0.9055 - val_loss: 0.3169 - val_accuracy: 0.8864
# Epoch 8/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2383 - accuracy: 0.9096 - val_loss: 0.3016 - val_accuracy: 0.8932
# Epoch 9/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2274 - accuracy: 0.9156 - val_loss: 0.3152 - val_accuracy: 0.8887
# Epoch 10/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2145 - accuracy: 0.9192 - val_loss: 0.3172 - val_accuracy: 0.8902
# [0.36768126487731934, 0.3300272822380066, 0.3073166012763977, 0.2908881604671478, 0.27354294061660767, 0.25953957438468933, 0.2473410815000534, 0.23825190961360931, 0.22738617658615112, 0.2145068347454071]
# [0.8651428818702698, 0.8778571486473083, 0.8855952620506287, 0.8927381038665771, 0.8983571529388428, 0.9024999737739563, 0.9054999947547913, 0.9095714092254639, 0.9156190752983093, 0.9192143082618713]
# [0.37350162863731384, 0.3504505753517151, 0.3236874043941498, 0.3329770863056183, 0.32351523637771606, 0.3303094208240509, 0.3168829083442688, 0.3015654981136322, 0.31522229313850403, 0.31715744733810425]
# [0.8663333058357239, 0.8733333349227905, 0.882444441318512, 0.879277765750885, 0.882777750492096, 0.883222222328186, 0.886388897895813, 0.8932222127914429, 0.8886666893959045, 0.8902222514152527]

# %%
import numpy as np
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    predicted_label = np.argmax(predict[i])
    true_label = y_test[i]
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(class_names[predicted_label],
                                class_names[true_label]),
               color=color)
plt.show()

# %% [markdown]
# - LogisticRegression

# %%
import warnings
from sklearn.linear_model import LogisticRegression
warnings.filterwarnings('ignore')

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
param_grid = {
    'tol': [0.0001, 0.001],
    'max_iter': [100, 200, 300]
}
grid = GridSearchCV(estimator=LogisticRegression(multi_class='multinomial'), param_grid=param_grid)
grid_result = grid.fit(X_train_flatten, y_train)
grid_result.best_params_
# Out:
# {'max_iter': 100, 'tol': 0.0001}

# %%
X_test_flatten = X_test.reshape(X_test.shape[0], -1)
lr_predict = grid_result.best_estimator_.predict(X_test_flatten)
lr_accuracy = accuracy_score(y_test, lr_predict)
lr_precision = precision_score(y_test, lr_predict, average='micro')
lr_recall = recall_score(y_test, lr_predict, average='micro')
lr_f1 = f1_score(y_test, predict, average='micro')
print('accuracy: ', lr_accuracy, 'precision: ', lr_precision, 'recall: ', lr_recall,'f1 :' , lr_f1)
# Out:
# accuracy:  0.8439 precision:  0.8439 recall:  0.8439 f1 : 0.8531

# %% [markdown]
# #### Task 2

# %%
import os
from PIL import Image
import numpy as np


test_img = []
img_names = []
for file in os.listdir('task2 pictures'):
    image = Image.open(f'task2 pictures/{file}').convert('L').resize((28, 28))
    img_data = np.array(image.getdata()) / 255
    # 背景色改为白色
    img_data[img_data == 1] = 0
    test_img.append(img_data)
    img_names.append(file.split('.')[0])
test_img = np.array(test_img).reshape(len(test_img), 28, 28)

# %%
from sklearn.model_selection import GridSearchCV

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
best_model = create_model(grid_result.best_params_['layer'])
# model = GridSearchCV()
best_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ba3368e6916d> in <module>
#       2
#       3 X_train_flatten = X_train.reshape(X_train.shape[0], -1)
# ----> 4 best_model = create_model(grid_result.best_params_['layer'])
#       5 # model = GridSearchCV()
#       6 best_model.fit(X_train, y_train)
#
# KeyError: 'layer'

# %%
y_test
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(1, 5, figsize=(10, 10)) 
predict = best_model.predict(test_img).argmax(1)
for i in range(5):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_img[i], cmap=plt.cm.binary)
    predicted_label = class_names[predict[i]]
    true_label = img_names[i]
    if true_label in predicted_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(predicted_label, true_label),color=color)
plt.show()

# %%
lr = LogisticRegression()
X_train_flatten = X_train.reshape(X_train.shape[0], -1)
lr.fit(X_train_flatten, y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(test_img.reshape(test_img.shape[0], -1))
# Out:
# array([8, 2, 6, 0, 1], dtype=uint8)

# %%
plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(1, 5, figsize=(10, 10)) 
predict = lr.predict(test_img.reshape(test_img.shape[0], -1))
for i in range(5):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_img[i], cmap=plt.cm.binary)
    predicted_label = class_names[predict[i]]
    true_label = img_names[i]
    if true_label in predicted_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(predicted_label, true_label),color=color)
plt.show()

# %% [markdown]
# - SVM

# %%
from sklearn.svm import SVC

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
param_grid = {
    'kernel': ['rbf', 'sigmoid'],
    'max_iter': [100, 200, 300]
}
grid = GridSearchCV(estimator=SVC(), param_grid=param_grid)
grid_result = grid.fit(X_train_flatten, y_train)
grid_result.best_params_

# %%
SVC?

# %%
p
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
keras.wrappers.scikit_learn.KerasClassifier?

# %%
# Training parameters.
learning_rate = 0.01
training_steps = 1000
# Out:
# 0.5

# %%
from sklearn.metrics import accuracy_score

accuracy_score([0, 1], [0, 0])
# Out:
# 0.5

# %% [markdown]
# ### Output

# %% [markdown]
# <ul>
#     <li>Make sure to put descriptive comments on your code</li>
#     <li>Use the markdown cell format in Jupiter to add your own interpretation to the result in each section.</li>
#     <li>Make sure to keep the output of your runs when you want to save the final version of the file.</li>
#     <li>The final work should be very well structured and should have a consistent flow of analysis.</li>
# </ul>

# %% [markdown]
# #### Due Date: Nov 9 2020 at 11:59 PM

# %% [markdown]
# ## Grading Criteria

# %% [markdown]
# <table style="width:400px;height:200px;border:1px black solid; background-color:white">
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Comprehensiveness</th>
#         <td style="text-align:center;border:1px black solid"><b>30%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Correctness</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Complete Report</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Clear Code</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Innovation (Extra)</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:center;border:1px black solid;color:red"><u>Total</u></th>
#         <td style="text-align:center;border:1px black solid;color:red"><b stlyle="color:red">110%</b></td>
#     </tr>
# </table>
