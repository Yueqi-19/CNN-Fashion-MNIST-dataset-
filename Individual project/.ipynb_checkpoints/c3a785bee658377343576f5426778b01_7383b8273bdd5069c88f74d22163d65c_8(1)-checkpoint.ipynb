# %% [markdown]
#         Data Science: A Programming Approach
#         Mahyar S Vaghefi
#         University of Texas Arlington
#
#         This document can only be used for class studies.
#         You are not allowed to share it in any public platform.

# %% [markdown]
# <h1 align='center' style="color: blue;">Individual Project - Fall 2020</h1>

# %% [markdown]
# You need to work on a popular Fashion MNIST dataset for this project. The dataset includes tiny images of fashion pieces. The objective is to create a set of supervised learning models that can predict the type of item based on its image. You can use all different models that you learned about them in this course for yourr work. Keep in mind that this is a project, not a class assignmnet. So, not all steps are predetermined and you have more flexibility, and the final outcome is likely to be more detailed.

# %% [markdown]
# In order to load the dataset you need to have `tensorflow V2` on your computer. Use the following code to install the package

# %%
#!pip install --upgrade tensorflow
#!pip install keras

# %% [markdown]
# You can also check the version of it using the following code.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.1'

# %% [markdown]
# Now, it's time to load the dataset

# %%
from tensorflow import keras
#from keras.utils import np_utils
fashion_mnist = keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# As can be seen from the above code, the dataset was divided into train and test sets. Let's take a look at the X_train

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# As it is clear, the train dataset (`X_train`) contains 60,000 images of size 28 x 28. We can visualize one of the images using the following code:

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

sample_image = X_train[1]
plt.imshow(sample_image, cmap='binary')
plt.axis('off')
plt.show()

# %% [markdown]
# The `y_train` also includes values between 0 and 9. Each represents a particular category. For example, we can check the value of `y_train` for the above image.

# %%
y_train[1]
# Out:
# 0

# %% [markdown]
# The above code shows that the image belongs to category 0. To get the associated label with each category, you can use the following code:

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
print(class_names[y_train[1]])
# Out:
# T-shirt/top

# %% [markdown]
# Now, it's your turn,

# %% [markdown]
# <ul>
#     <li><b>Task1:</b> Use the train set to train various supervised models and evaluate their performance using the test set.</li>
#     <ul>
#         <li>Use different supervised learning models.</li>
#         <li>Use different metrics such as <b>accutacy</b>, <b>precision</b>, <b>AUC</b>, and ... in your model evaluation. </li>
#         <li>It is not enough to report the metrics. It is crucial that you interpret the metrics for each model and compare them across different models.</li>
#         <li> You may need to use the cross validation methods for hyperparameter selection.</li>
#         <li> Specify the model that outperforms the other models.</b>
#     </ul>
#     <li><b>Task2:</b> Use the best model to predict your own fashion pieces.</li>
#     <ul>
#         <li>Take a picture of five fashion pieces of your own (take pictures in square format).</li>
#         <li>Resize images to the correct size (28,28).</li>
#         <li>Grayscale your images.</li>
#         <li>Visualize all the images side by side</li>
#         <li>Use the best model in Task 1 to predict the label of each of your own images.</li>
#         <li>How accurate is the final result?</li>
#     </ul>
# </ul>

# %% [markdown]
# #### Task 1

# %%
#探索数据
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from sklearn.metrics import classification_report

# %%
print("The shape of train_images is ",X_train.shape)
print("The shape of train_labels is ",y_train.shape)
print("The shape of test_images is ",X_test.shape)
print("The length of test_labels is ",len(y_test))
# Out:
# The shape of train_images is  (60000, 28, 28)
# The shape of train_labels is  (60000,)
# The shape of test_images is  (10000, 28, 28)
# The length of test_labels is  10000

# %%
plt.figure()
plt.imshow(X_train[0])
plt.colorbar()
plt.gca().grid(False)
plt.show()

# %%
# normalize to range 0-1 将像素值缩小到 0 到 1 之间
X_train=X_train/255.0
X_test=X_test/255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_train[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
    
plt.show()

# %%
# model=keras.Sequential([
#     keras.layers.Flatten(input_shape=(28,28)),
#     keras.layers.Dense(128,activation=tf.nn.relu),
#     keras.layers.Dense(10,activation=tf.nn.softmax)
# ])

# %%
# model.compile(optimizer=tf.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
# # record model performance on a validation dataset during training
# model.compile(optimizer=tf.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# history = model.fit(X_train,y_train,epochs=10,validation_split=0.3)
# print(history.history['loss'])
# print(history.history['accuracy'])
# print(history.history['val_loss'])
# print(history.history['val_accuracy'])

# %%
# make predictions on the test set

# # show a nicely formatted classification report
# from sklearn.metrics import classification_report, confusion_matrix
# import sklearn.metrics as metrics
# import numpy as np

# preds = model.predict(X_test)

# print("--------------------classification_report------------------")

# print(metrics.classification_report (y_test, np.argmax(preds, axis = 1),target_names=class_names))

# #plot the training loss and accuracy

# plt.style.use("ggplot")
# plt.figure()
# plt.plot(np.arange(0, 10), history.history["loss"], label="train_loss")
# plt.plot(np.arange(0, 10), history.history["val_loss"], label="val_loss")
# plt.plot(np.arange(0, 10), history.history["accuracy"], label="train_acc")
# plt.plot(np.arange(0, 10), history.history["val_accuracy"], label="val_acc")

# plt.title("Training Loss and Accuracy on Dataset")
# plt.xlabel("Epoch number ")
# plt.ylabel("Loss/Accuracy")
# plt.legend(loc="lower left")
# plt.savefig("plot.png")

# %%
# loss, accuracy = model.evaluate(X_test, y_test)
# print('\ntest loss:', loss)
# print('test_accuracy:', accuracy)

# %%
# model=keras.Sequential([
#     keras.layers.Flatten(input_shape=(28,28)),
#     keras.layers.Dense(128,activation=tf.nn.relu),
#     keras.layers.Dense(10,activation=tf.nn.softmax)
# ])

# %%
# model.compile(optimizer=tf.optimizers.Adam(),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
# model.fit(X_train,y_train,batch_size=64,epochs=10)

# %%
# loss, accuracy = model.evaluate(X_test, y_test)
# print('\ntest loss:', loss)
# print('accuracy:', accuracy)

# %%
# import numpy as np
# predictions=model.predict(X_test)
# print("The first picture's prediction is:{},so the result is:{}".format(predictions[0],np.argmax(predictions[0])))
# print("The first picture is ",X_test[0])

# %%
# import numpy as np
# plt.figure(figsize=(10, 10))
# for i in range(25):
#     plt.subplot(5, 5, i + 1)
#     plt.xticks([])
#     plt.yticks([])
#     plt.grid('off')
#     plt.imshow(X_test[i], cmap=plt.cm.binary)
#     predicted_label = np.argmax(preds[i])
#     true_label = y_test[i]
#     if predicted_label == true_label:
#         color = 'green'
#     else:
#         color = 'red'
#     plt.xlabel("{} ({})".format(class_names[predicted_label],
#                                 class_names[true_label]),
#                color=color)
# plt.show()

# %% [markdown]
# - 神经网络

# %%
from sklearn.model_selection import GridSearchCV

def create_model(layer):
    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(28, 28)),
        keras.layers.Dense(layer, activation='relu'),
        keras.layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

model = keras.wrappers.scikit_learn.KerasClassifier(create_model)
param_grid = {'layer': [32, 64, 128, 256]}
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1)
grid_result = grid.fit(X_train,y_train)
# Out:
# 1500/1500 [==============================] - 1s 893us/step - loss: 0.5668 - accuracy: 0.8040
# 375/375 [==============================] - 0s 548us/step - loss: 0.4433 - accuracy: 0.8472
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5688 - accuracy: 0.8064
# 375/375 [==============================] - 0s 559us/step - loss: 0.4653 - accuracy: 0.8366
# 1500/1500 [==============================] - 1s 894us/step - loss: 0.5798 - accuracy: 0.8021
# 375/375 [==============================] - 0s 668us/step - loss: 0.4489 - accuracy: 0.8468
# 1500/1500 [==============================] - 1s 787us/step - loss: 0.5729 - accuracy: 0.8046
# 375/375 [==============================] - 0s 662us/step - loss: 0.5133 - accuracy: 0.8188
# 1500/1500 [==============================] - 1s 918us/step - loss: 0.5805 - accuracy: 0.8019
# 375/375 [==============================] - 0s 564us/step - loss: 0.4468 - accuracy: 0.8471
# 1500/1500 [==============================] - 1s 856us/step - loss: 0.5384 - accuracy: 0.8136
# 375/375 [==============================] - 0s 622us/step - loss: 0.4607 - accuracy: 0.8308
# 1500/1500 [==============================] - 1s 836us/step - loss: 0.5381 - accuracy: 0.8146
# 375/375 [==============================] - 0s 606us/step - loss: 0.4559 - accuracy: 0.8363
# 1500/1500 [==============================] - 1s 796us/step - loss: 0.5450 - accuracy: 0.8124
# 375/375 [==============================] - 0s 633us/step - loss: 0.4224 - accuracy: 0.8550
# 1500/1500 [==============================] - 1s 822us/step - loss: 0.5375 - accuracy: 0.8119
# 375/375 [==============================] - 0s 641us/step - loss: 0.4429 - accuracy: 0.8461
# 1500/1500 [==============================] - 1s 940us/step - loss: 0.5490 - accuracy: 0.8119
# 375/375 [==============================] - 0s 633us/step - loss: 0.5000 - accuracy: 0.8322
# 1500/1500 [==============================] - 1s 979us/step - loss: 0.5209 - accuracy: 0.8175
# 375/375 [==============================] - 0s 715us/step - loss: 0.4108 - accuracy: 0.8535
# 1500/1500 [==============================] - 1s 997us/step - loss: 0.5156 - accuracy: 0.8211
# 375/375 [==============================] - 0s 668us/step - loss: 0.4829 - accuracy: 0.8251
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5200 - accuracy: 0.8178
# 375/375 [==============================] - 0s 713us/step - loss: 0.4147 - accuracy: 0.8518
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5175 - accuracy: 0.8162
# 375/375 [==============================] - 0s 726us/step - loss: 0.4279 - accuracy: 0.8504
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5194 - accuracy: 0.8197
# 375/375 [==============================] - 0s 707us/step - loss: 0.4118 - accuracy: 0.8534
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5097 - accuracy: 0.8201
# 375/375 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8497
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5042 - accuracy: 0.8223
# 375/375 [==============================] - 0s 806us/step - loss: 0.3979 - accuracy: 0.8546
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5025 - accuracy: 0.8214
# 375/375 [==============================] - 0s 854us/step - loss: 0.4019 - accuracy: 0.8608
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5030 - accuracy: 0.8216
# 375/375 [==============================] - 0s 979us/step - loss: 0.4077 - accuracy: 0.8565
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.5049 - accuracy: 0.8212
# 375/375 [==============================] - 0s 878us/step - loss: 0.4085 - accuracy: 0.8528
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4834 - accuracy: 0.8295

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import classification_report, confusion_matrix
import sklearn.metrics as metrics
import numpy as np


best_model = create_model(grid_result.best_params_['layer'])
best_model.fit(X_train, y_train)
predict = best_model.predict(X_test)


#print('accuracy: ', accuracy)

print("\n--------------------classification_report------------------")

print(metrics.classification_report (y_test, np.argmax(predict, axis = 1),target_names=class_names))
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4839 - accuracy: 0.8268
#
# --------------------classification_report------------------
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.78      0.84      0.81      1000
#      Trouser       0.99      0.95      0.97      1000
#     Pullover       0.58      0.91      0.71      1000
#        Dress       0.76      0.91      0.83      1000
#         Coat       0.84      0.38      0.53      1000
#       Sandal       0.97      0.92      0.95      1000
#        Shirt       0.69      0.47      0.56      1000
#      Sneaker       0.91      0.92      0.92      1000
#          Bag       0.94      0.97      0.95      1000
#   Ankle boot       0.92      0.96      0.94      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.84      0.82      0.82     10000
# weighted avg       0.84      0.82      0.82     10000

# %%
# Fit the model

history = best_model.fit(X_train,y_train,epochs=10,validation_split=0.3)
print(history.history['loss'])
print(history.history['accuracy'])
print(history.history['val_loss'])
print(history.history['val_accuracy'])



# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')

plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left') 
plt.show()

# summarize history for loss plt.plot(history.history['loss']) plt.plot(history.history['val_loss']) plt.title('model loss')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left') 
plt.show()

#plot the training loss and accuracy

plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 10), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, 10), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, 10), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, 10), history.history["val_accuracy"], label="val_acc")

plt.title("Training Loss and Accuracy on Dataset")
plt.xlabel("Epoch number ")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("plot.png")
plt.show()
# Out:
# Epoch 1/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3678 - accuracy: 0.8660 - val_loss: 0.3429 - val_accuracy: 0.8772
# Epoch 2/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3307 - accuracy: 0.8805 - val_loss: 0.3250 - val_accuracy: 0.8832
# Epoch 3/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.3068 - accuracy: 0.8866 - val_loss: 0.3522 - val_accuracy: 0.8692
# Epoch 4/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2890 - accuracy: 0.8910 - val_loss: 0.3167 - val_accuracy: 0.8851
# Epoch 5/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2724 - accuracy: 0.8976 - val_loss: 0.3481 - val_accuracy: 0.8754
# Epoch 6/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2598 - accuracy: 0.9031 - val_loss: 0.3299 - val_accuracy: 0.8830
# Epoch 7/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2479 - accuracy: 0.9058 - val_loss: 0.3113 - val_accuracy: 0.8903
# Epoch 8/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2378 - accuracy: 0.9087 - val_loss: 0.3273 - val_accuracy: 0.8827
# Epoch 9/10
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.2281 - accuracy: 0.9132 - val_loss: 0.3124 - val_accuracy: 0.8905
# Epoch 10/10
#  848/1313 [==================>...........] - ETA: 0s - loss: 0.2197 - accuracy: 0.9160

# %%
import numpy as np
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    predicted_label = np.argmax(predict[i])
    true_label = y_test[i]
    if predicted_label == true_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(class_names[predicted_label],
                                class_names[true_label]),
               color=color)
plt.show()

# %% [markdown]
# - LogisticRegression

# %%
import warnings
from sklearn.linear_model import LogisticRegression
warnings.filterwarnings('ignore')

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
param_grid = {
    'tol': [0.0001, 0.001],
    'max_iter': [100, 200, 300]
}
grid = GridSearchCV(estimator=LogisticRegression(multi_class='multinomial'), param_grid=param_grid)
grid_result = grid.fit(X_train_flatten, y_train)
grid_result.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-ec0ba6c9784b> in <module>
#       9 }
#      10 grid = GridSearchCV(estimator=LogisticRegression(multi_class='multinomial'), param_grid=param_grid)
# ---> 11 grid_result = grid.fit(X_train_flatten, y_train)
#      12 grid_result.best_params_
#
# d:\python36\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# d:\python36\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# d:\python36\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# d:\python36\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# d:\python36\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# d:\python36\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# d:\python36\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# d:\python36\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# d:\python36\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# d:\python36\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# d:\python36\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# d:\python36\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# d:\python36\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1415                       penalty=penalty, max_squared_sum=max_squared_sum,
#    1416                       sample_weight=sample_weight)
# -> 1417             for class_, warm_start_coef_ in zip(classes_, warm_start_coef))
#    1418
#    1419         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# d:\python36\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# d:\python36\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# d:\python36\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# d:\python36\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# d:\python36\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# d:\python36\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# d:\python36\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# d:\python36\lib\site-packages\sklearn\linear_model\_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio)
#     758                 func, w0, method="L-BFGS-B", jac=True,
#     759                 args=(X, target, 1. / C, sample_weight),
# --> 760                 options={"iprint": iprint, "gtol": tol, "maxiter": max_iter}
#     761             )
#     762             n_iter_i = _check_optimize_result(
#
# d:\python36\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# d:\python36\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# d:\python36\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     293     else:
#     294         def func_and_grad(x):
# --> 295             f = fun(x, *args)
#     296             g = jac(x, *args)
#     297             return f, g
#
# d:\python36\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# d:\python36\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      63     def __call__(self, x, *args):
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#      67         return fg[0]
#
# d:\python36\lib\site-packages\sklearn\linear_model\_logistic.py in func(x, *args)
#     733         target = Y_multi
#     734         if solver == 'lbfgs':
# --> 735             def func(x, *args): return _multinomial_loss_grad(x, *args)[0:2]
#     736         elif solver == 'newton-cg':
#     737             def func(x, *args): return _multinomial_loss(x, *args)[0]
#
# d:\python36\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss_grad(w, X, Y, alpha, sample_weight)
#     345     grad = np.zeros((n_classes, n_features + bool(fit_intercept)),
#     346                     dtype=X.dtype)
# --> 347     loss, p, w = _multinomial_loss(w, X, Y, alpha, sample_weight)
#     348     sample_weight = sample_weight[:, np.newaxis]
#     349     diff = sample_weight * (p - Y)
#
# d:\python36\lib\site-packages\sklearn\linear_model\_logistic.py in _multinomial_loss(w, X, Y, alpha, sample_weight)
#     293     else:
#     294         intercept = 0
# --> 295     p = safe_sparse_dot(X, w.T)
#     296     p += intercept
#     297     p -= logsumexp(p, axis=1)[:, np.newaxis]
#
# d:\python36\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# d:\python36\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
X_test_flatten = X_test.reshape(X_test.shape[0], -1)
lr_predict = grid_result.best_estimator_.predict(X_test_flatten)
lr_accuracy = accuracy_score(y_test, lr_predict)
lr_precision = precision_score(y_test, lr_predict, average='micro')
lr_recall = recall_score(y_test, lr_predict, average='micro')
print('accuracy: ', lr_accuracy, 'precision: ', lr_precision, 'recall: ', lr_recall)
# Out:
# accuracy:  0.8439 precision:  0.8439 recall:  0.8439

# %% [markdown]
# #### Task 2

# %%
import os
from PIL import Image
import numpy as np


test_img = []
img_names = []
for file in os.listdir('task2 pictures'):
    image = Image.open(f'task2 pictures/{file}').convert('L').resize((28, 28))
    img_data = np.array(image.getdata()) / 255
    # 背景色改为白色
    img_data[img_data == 1] = 0
    test_img.append(img_data)
    img_names.append(file.split('.')[0])
test_img = np.array(test_img).reshape(len(test_img), 28, 28)

# %%
from sklearn.model_selection import GridSearchCV

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
model = create_model(grid_result.best_params_['layer'])
# model = GridSearchCV()
model.fit(X_train, y_train)
# Out:
# 1875/1875 [==============================] - 1s 605us/step - loss: 0.5002 - accuracy: 0.8240

# %%
y_test
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(1, 5, figsize=(10, 10)) 
predict = model.predict(test_img).argmax(1)
for i in range(5):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_img[i], cmap=plt.cm.binary)
    predicted_label = class_names[predict[i]]
    true_label = img_names[i]
    if true_label in predicted_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(predicted_label, true_label),color=color)
plt.show()
# for i, axi in enumerate(ax.flat):
#     axi.imshow(test_img[i].reshape(28, 28), cmap='binary')
#     axi.set_title(img_names[i])
#     predict = best_model.predict(test_img[i].reshape(1, 28, 28)).argmax(1)[0]
#     axi.set_xlabel(f'predict: {class_names[predict]}')

# %%
lr = LogisticRegression()
X_train_flatten = X_train.reshape(X_train.shape[0], -1)
lr.fit(X_train_flatten, y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(test_img.reshape(test_img.shape[0], -1))
# Out:
# array([8, 2, 6, 0, 1], dtype=uint8)

# %%
plt.figure(figsize=(10, 10))
fig, ax = plt.subplots(1, 5, figsize=(10, 10)) 
predict = lr.predict(test_img.reshape(test_img.shape[0], -1))
for i in range(5):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(test_img[i], cmap=plt.cm.binary)
    predicted_label = class_names[predict[i]]
    true_label = img_names[i]
    if true_label in predicted_label:
        color = 'green'
    else:
        color = 'red'
    plt.xlabel("{} ({})".format(predicted_label, true_label),color=color)
plt.show()

# %% [markdown]
# - predict

# %%
fig, ax = plt.subplots(1, 5, figsize=(10, 10)) 
for i, axi in enumerate(ax.flat):
    axi.imshow(test_img[i].reshape(28, 28), cmap='binary')
    axi.set_title(img_names[i])
    predict = best_model.predict(test_img[i].reshape(1, 28, 28)).argmax(1)[0]
    axi.set_xlabel(f'predict: {class_names[predict]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3e689d2c4565> in <module>
#       3     axi.imshow(test_img[i].reshape(28, 28), cmap='binary')
#       4     axi.set_title(img_names[i])
# ----> 5     predict = best_model.predict(test_img[i].reshape(1, 28, 28)).argmax(1)[0]
#       6     axi.set_xlabel(f'predict: {class_names[predict]}')
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# - SVM

# %%
from sklearn.svm import SVC

X_train_flatten = X_train.reshape(X_train.shape[0], -1)
param_grid = {
    'kernel': ['rbf', 'sigmoid'],
    'max_iter': [100, 200, 300]
}
grid = GridSearchCV(estimator=SVC(), param_grid=param_grid)
grid_result = grid.fit(X_train_flatten, y_train)
grid_result.best_params_

# %%
SVC?

# %%
p
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
keras.wrappers.scikit_learn.KerasClassifier?

# %%
# Training parameters.
learning_rate = 0.01
training_steps = 1000
# Out:
# 0.5

# %%
from sklearn.metrics import accuracy_score

accuracy_score([0, 1], [0, 0])
# Out:
# 0.5

# %% [markdown]
# ### Output

# %% [markdown]
# <ul>
#     <li>Make sure to put descriptive comments on your code</li>
#     <li>Use the markdown cell format in Jupiter to add your own interpretation to the result in each section.</li>
#     <li>Make sure to keep the output of your runs when you want to save the final version of the file.</li>
#     <li>The final work should be very well structured and should have a consistent flow of analysis.</li>
# </ul>

# %% [markdown]
# #### Due Date: Nov 9 2020 at 11:59 PM

# %% [markdown]
# ## Grading Criteria

# %% [markdown]
# <table style="width:400px;height:200px;border:1px black solid; background-color:white">
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Comprehensiveness</th>
#         <td style="text-align:center;border:1px black solid"><b>30%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Correctness</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Complete Report</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Clear Code</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:left;border:1px black solid">Innovation (Extra)</th>
#         <td style="text-align:center;border:1px black solid"><b>20%</b></td>
#     </tr>
#     <tr style="background-color:white">
#         <th style="text-align:center;border:1px black solid;color:red"><u>Total</u></th>
#         <td style="text-align:center;border:1px black solid;color:red"><b stlyle="color:red">110%</b></td>
#     </tr>
# </table>
